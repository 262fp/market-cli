# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/S08_Funciones_Recursividad.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 8: Subprogramas, funciones y recursividad
#
# ## Objetivo
# Modularizar el proyecto mediante funciones con parámetros y retorno, e implementar un laboratorio básico de algoritmos recursivos.
#
# ## Producto de la sesión
# Construye un CRUD modular y un laboratorio de algoritmos recursivos.
#
# ## Resultado esperado
# Separa el programa en funciones claras para registrar, listar, buscar, ordenar y mostrar información, reduciendo repetición de código.
#
# ## Alcance de la sesión
# - Subprogramas y funciones.
# - Parámetros y retorno.
# - Modularización del CRUD.
# - Separación de responsabilidades.
# - Recursividad como laboratorio complementario.
#
# ## Idea fuerza
# Cuando el CRUD crece, el menú ya no debe concentrar todo el código. Las funciones permiten ordenar el proyecto y preparar la integración final.

# %% [markdown]
# ## Base conceptual de la sesión
#
# **Función**
#
# Agrupa instrucciones que resuelven una tarea concreta.
#
# ```python
# def saludar(nombre):
#     print('Hola', nombre)
# ```
#
# **Parámetros**
#
# Son datos que la función recibe para trabajar.
#
# **Retorno**
#
# Es el valor que una función devuelve.
#
# **Recursividad**
#
# Una función recursiva se llama a sí misma y necesita un caso base para detenerse.

# %% [markdown]
# ## Actividad práctica
#
# Reorganiza el proyecto usando funciones.
#
# ### Funciones mínimas
#
# - `mostrar_menu()`
# - `registrar()`
# - `listar()`
# - `buscar()`
# - `ordenar()`

# %%
nombres = []
precios = []


def registrar(nombres, precios):
    nombre = input('Nombre: ')
    precio = float(input('Precio: '))
    nombres.append(nombre)
    precios.append(precio)


def listar(nombres, precios):
    for i in range(len(nombres)):
        print(i + 1, nombres[i], precios[i])


def contar_registros(nombres):
    return len(nombres)

# %%
# Laboratorio recursivo: factorial

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

print(factorial(5))

# %% [markdown]
# ## Aprendizaje autónomo
#
# **1** Convierte cada opción del menú en una función.
#
# **2** Usa parámetros para enviar las listas a las funciones.
#
# **3** Usa retorno en al menos una función de cálculo o búsqueda.
#
# **4** Implementa un algoritmo recursivo clásico: factorial, suma de números o potencia.

# %%
# Producto de sesión: CRUD modular y laboratorio recursivo

# %% [markdown]
# ## Evaluación del producto de la sesión
#
# Lista de cotejo:
#
# - [ ] El proyecto está organizado en funciones claras.
# - [ ] Las funciones usan parámetros cuando corresponde.
# - [ ] Al menos una función retorna un valor útil.
# - [ ] El menú llama a funciones en lugar de concentrar todo el código.
# - [ ] Incluye un laboratorio recursivo con caso base y llamada recursiva.
