# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/S12_Evaluacion_2.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 12: Evaluación Unidad 2
#
# ## Objetivo
# Evaluar la aplicación de estructuras repetitivas, arreglos/listas, búsqueda, ordenación, funciones, matrices, diccionarios, consultas y reportes en el Producto U2.
#
# ## Producto de la sesión
# Sustenta una aplicación de consola con CRUD en memoria y procesamiento de datos.
#
# ## Resultado esperado
# Integra el avance de la Unidad 2 en una aplicación funcional con menú, registros en memoria, búsqueda, ordenación, modularización, consultas y reportes.
#
# ## Alcance de la sesión
# - Registro y listado de datos en memoria.
# - Menú interactivo validado.
# - Búsqueda y ordenación.
# - Modularización con funciones.
# - Uso de matrices o diccionarios según el problema.
# - Consultas, agregaciones y reportes.

# %% [markdown]
# ## Indicaciones
#
# Presenta el Producto U2 funcionando en consola. La aplicación debe conservar el avance de la Unidad 1 y agregar procesamiento de datos en memoria.
#
# Antes de sustentar, verifica:
#
# - que el menú funcione hasta salir,
# - que los datos se registren y listen correctamente,
# - que la búsqueda y ordenación funcionen,
# - que el código esté organizado en funciones,
# - que exista al menos un reporte o consulta agregada.

# %% [markdown]
# ## Requisitos mínimos del Producto U2
#
# 1. Menú principal interactivo.
# 2. Registrar registros de la entidad del proyecto.
# 3. Listar registros guardados en memoria.
# 4. Buscar registros por un campo definido.
# 5. Ordenar registros por un criterio.
# 6. Usar funciones para modularizar operaciones.
# 7. Usar matriz o diccionario cuando corresponda.
# 8. Mostrar consultas, agregaciones o reportes.

# %%
# Espacio para integrar o pegar la versión final del Producto U2

# %% [markdown]
# ## Evaluación del producto de la sesión
#
# Lista de cotejo:
#
# - [ ] La aplicación conserva el avance del Producto U1.
# - [ ] Implementa CRUD básico en memoria.
# - [ ] Usa menú interactivo con validaciones.
# - [ ] Implementa búsqueda y ordenación.
# - [ ] Organiza el código en funciones.
# - [ ] Usa matrices o diccionarios de manera pertinente.
# - [ ] Incluye consultas, agregaciones o reportes.
# - [ ] Sustenta el funcionamiento con evidencias y casos de prueba.
