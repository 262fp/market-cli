# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/S12_Evaluacion_2.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesion 12: Evaluacion Unidad 2
#
# ## Objetivo
# Evaluar la integracion de estructuras repetitivas, listas, menu interactivo, funciones, busqueda, ordenacion, archivos basicos, consultas y reportes en el Producto U2.
#
# ## Producto de la sesion
# Sustenta una aplicacion de consola con CRUD modular, memoria, archivos basicos y consultas.
#
# ## Resultado esperado
# Integra el avance de la Unidad 2 en una aplicacion funcional con menu, registros en memoria, busqueda, ordenacion, funciones, persistencia simple en archivos y reportes de consola.
#
# ## Alcance de la sesion
# - Registro y listado de datos en memoria.
# - Menu interactivo validado.
# - Busqueda y ordenacion.
# - Modularizacion con funciones.
# - Guardado y carga desde archivo.
# - Consultas, agregaciones y reportes.

# %% [markdown]
# ## Indicaciones
#
# Presenta el Producto U2 funcionando en consola. La aplicacion debe conservar el avance de la Unidad 1 y agregar procesamiento de datos con memoria, funciones y archivos.
#
# Antes de sustentar, verifica:
#
# - que el menu funcione hasta salir,
# - que los datos se registren y listen correctamente,
# - que la busqueda y ordenacion funcionen,
# - que el codigo este organizado en funciones,
# - que la aplicacion guarde y cargue registros desde archivo,
# - que exista al menos un reporte o consulta agregada.

# %% [markdown]
# ## Requisitos minimos del Producto U2
#
# 1. Menu principal interactivo.
# 2. Registrar registros de la entidad del proyecto.
# 3. Listar registros guardados en memoria.
# 4. Buscar registros por un campo definido.
# 5. Editar y eliminar registros.
# 6. Ordenar registros por un criterio.
# 7. Usar funciones para modularizar operaciones.
# 8. Guardar y cargar datos desde archivo.
# 9. Mostrar consultas, agregaciones o reportes.

# %%
# Lista de cotejo del Producto U2
criterios = [
    "Menu interactivo",
    "Registrar",
    "Listar",
    "Buscar",
    "Editar",
    "Eliminar",
    "Ordenar",
    "Funciones",
    "Guardar y cargar archivo",
    "Reportes"
]

for criterio in criterios:
    print("[ ]", criterio)

# %% [markdown]
# ## Evaluacion del producto de la unidad
#
# El Producto U2 se considera logrado si la aplicacion permite gestionar registros completos, conservarlos en archivo y generar informacion resumida desde esos datos.
