# %% [markdown]
# # Sesión 05. Evaluación de la Unidad I
#
# **Unidad:** Unidad I
# **Propósito:** Integrar algoritmos, programación secuencial, decisiones y funciones.
# **Evidencia de la sesión:** Portafolio funcional de soluciones algorítmicas de la Unidad I.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Interpretación del problema y modelo EPS.
# - Conversión del pseudocódigo a Python.
# - Secuencias, condiciones y funciones.
# - Verificación con pruebas de escritorio y casos representativos.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
def puede_vender(stock, cantidad):
    return cantidad > 0 and cantidad <= stock

def total_linea(precio, cantidad):
    return precio * cantidad

assert puede_vender(5, 5)
assert not puede_vender(5, 6)
assert total_linea(4.5, 2) == 9.0

# %% [markdown]
# ## Reto de aplicación
#
# Resuelva el caso asignado sin utilizar ciclos ni colecciones. Entregue pseudocódigo, código organizado en funciones y evidencias de ejecución.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] La solución respeta el alcance de la Unidad I.
# - [ ] Las funciones producen resultados verificables.
# - [ ] Explica las decisiones tomadas.
