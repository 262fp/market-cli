# %% [markdown]
# # Sesión 15. Sustentación del Proyecto Integrador Final
#
# **Unidad:** Unidad III
# **Propósito:** Demostrar el producto integrado y sustentar las decisiones algorítmicas y estructurales.
# **Evidencia de la sesión:** Proyecto Integrador Final CLI ejecutable, documentado y sustentado.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Demostración del problema, alcance y flujo principal.
# - Integración de funciones, validaciones, ciclos y estructuras de datos.
# - Persistencia mediante instantánea de archivos.
# - Justificación de algoritmos y estructuras seleccionadas.
# - Evidencias de evolución desde los productos de las unidades.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
def verificar_entrega(entrega):
    criterios = ["ejecutable", "datos", "operaciones", "documentacion", "sustentacion"]
    faltantes = [criterio for criterio in criterios if not entrega.get(criterio)]
    return faltantes

evidencia = {
    "ejecutable": True,
    "datos": True,
    "operaciones": True,
    "documentacion": True,
    "sustentacion": True,
}
assert verificar_entrega(evidencia) == []

# %% [markdown]
# ## Reto de aplicación
#
# Realice una demostración reproducible del flujo principal, explique una decisión algorítmica y responda preguntas sobre su propio código.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] El proyecto inicia y carga datos.
# - [ ] Demuestra operaciones y guardado.
# - [ ] Cada integrante explica decisiones del código.
