# %% [markdown]
# <a href="https://colab.research.google.com/github/262fp/market-cli/blob/main/docs/S15_Sustentacion_Proyecto_Integrador.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 15: Sustentación del Proyecto Integrador Final
#
# ## Objetivo
# Preparar y presentar técnicamente la aplicación de consola desarrollada durante el semestre.
#
# ## Producto de la sesión
# Sustenta el producto final: aplicación de consola completa para la gestión de una entidad.
#
# ## Resultado esperado
# El estudiante demuestra el funcionamiento de la aplicación, explica su estructura, presenta evidencias y responde preguntas técnicas sobre las decisiones implementadas.
#
# ## Alcance de la sesión
# - Preparación de la demo funcional.
# - Revisión de requisitos del producto final.
# - Evidencias de ejecución.
# - Explicación del flujo principal.
# - Explicación de estructuras usadas.
# - Sustentación técnica y mejoras finales.
#
# ## Idea fuerza
# La sustentación no es solo mostrar que el programa corre. Es explicar cómo el producto evolucionó desde una ficha con variables hasta una aplicación con menú, CRUD, procesamiento, archivos y reportes.

# %% [markdown]
# ## Guion de sustentación
#
# 1. Presentar el problema o entidad gestionada.
# 2. Mostrar el menú principal.
# 3. Registrar datos.
# 4. Listar, buscar, ordenar o actualizar información.
# 5. Mostrar consultas y resultados acumulados pertinentes.
# 6. Guardar y recuperar datos desde archivos.
# 7. Mostrar la carga inicial y el reemplazo de la instantánea.
# 8. Explicar funciones, estructuras de datos y validaciones.
# 9. Presentar evidencias de prueba.

# %% [markdown]
# ## Actividad práctica
#
# Prepara la demo final del producto.
#
# ### Evidencias mínimas
#
# - Capturas o salidas de ejecución.
# - Archivo de datos persistidos.
# - Evidencia de la estructura de datos integrada.
# - Casos de prueba.
# - Breve explicación del código.

# %%
# Espacio para pegar comandos, salidas o evidencia técnica de la demo

# %% [markdown]
# ## Aprendizaje autónomo
#
# **1**
# Ensaya la demostración con un flujo completo.
#
# **2**
# Corrige errores de mensajes, validaciones o navegación.
#
# **3**
# Organiza evidencias de ejecución y archivos generados.
#
# **4**
# Prepara respuestas para explicar las estructuras usadas: listas, funciones, algoritmos, estructuras pertinentes y archivos.

# %% [markdown]
# ## Evaluación del producto de la sesión
#
# Lista de cotejo:
#
# - [ ] La aplicación ejecuta el flujo principal sin errores.
# - [ ] El menú y las operaciones principales funcionan.
# - [ ] La aplicación guarda y recupera datos.
# - [ ] La aplicación presenta resultados útiles y una instantánea recuperable.
# - [ ] El estudiante explica la estructura del código y las decisiones tomadas.
# - [ ] Presenta evidencias de funcionamiento.
