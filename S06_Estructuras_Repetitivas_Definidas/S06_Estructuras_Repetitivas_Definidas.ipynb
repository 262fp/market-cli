# %% [markdown]
# <a href="https://colab.research.google.com/github/262fp/market-cli/blob/main/docs/S06_Estructuras_Repetitivas_Definidas.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 6: Estructuras repetitivas definidas con for
#
# ## Objetivo
# Convertir la entidad trabajada con variables individuales en una colección de registros usando arreglos/listas y recorridos con `for`.
#
# ## Producto de la sesión
# Implementa un CRUD básico en memoria usando arreglos/listas: registrar y listar registros del proyecto.
#
# ## Resultado esperado
# Construye una primera versión del almacenamiento en memoria, registra varios elementos de la entidad elegida y los recorre con `for` para mostrarlos de forma ordenada.
#
# ## Alcance de la sesión
# - Relación con S1: de una ficha con variables sueltas a una colección de registros.
# - Estructuras lineales: arreglos/listas.
# - Recorrido con `for` y `range`.
# - Contadores, acumuladores y listado de registros.
# - Inicio del CRUD en memoria: registrar y listar.
#
# ## Idea fuerza
# En la Unidad 1 se trabajó una entidad usando variables individuales. En esta sesión esa entidad se convierte en una colección de registros, permitiendo almacenar y recorrer varios datos con `for`.

# %% [markdown]
# ## Base conceptual de la sesión
#
# **Estructura lineal**
#
# Una estructura lineal permite guardar varios datos en una secuencia. En Python usaremos listas.
#
# ```python
# nombres = []
# precios = []
# stocks = []
# ```
#
# **Recorrido con for**
#
# `for` permite repetir una acción una cantidad conocida de veces o recorrer los elementos de una lista.
#
# **CRUD inicial**
#
# En esta sesión se implementan las dos primeras operaciones: registrar y listar.

# %% [markdown]
# ## Actividad práctica
#
# Construye el primer almacenamiento en memoria del proyecto.
#
# ### Arquitectura
#
# ```text
# Entrada -> Registro en listas -> Recorrido con for -> Salida
# ```
#
# ### Pasos
#
# 1. Define los campos principales de tu entidad.
# 2. Crea una lista por cada campo.
# 3. Registra varios elementos con `append()`.
# 4. Recorre las listas con `for`.
# 5. Muestra los registros en formato ordenado.

# %%
# CRUD inicial para productos usando listas paralelas
nombres = []
precios = []
stocks = []

cantidad = int(input('Cantidad de productos a registrar: '))

for i in range(cantidad):
    print('Producto', i + 1)
    nombre = input('Nombre: ')
    precio = float(input('Precio: '))
    stock = int(input('Stock: '))

    nombres.append(nombre)
    precios.append(precio)
    stocks.append(stock)

print('\nLISTADO DE PRODUCTOS')
for i in range(len(nombres)):
    print(i + 1, nombres[i], 'Precio:', precios[i], 'Stock:', stocks[i])

# %% [markdown]
# ## Aprendizaje autónomo
#
# Adapta el ejemplo a la entidad de tu proyecto.
#
# **1** Agrega al menos tres campos por registro.
#
# **2** Registra como mínimo cinco elementos.
#
# **3** Muestra el listado con numeración y formato claro.
#
# **4** Calcula un resumen simple usando `for`, por ejemplo cantidad total, stock total, importe acumulado o promedio.

# %%
# Producto de sesión: CRUD básico en memoria usando listas

# %% [markdown]
# ## Evaluación del producto de la sesión
#
# Lista de cotejo:
#
# - [ ] Define una entidad coherente con el proyecto.
# - [ ] Usa listas para almacenar varios registros.
# - [ ] Registra datos mediante entrada por teclado o datos de prueba.
# - [ ] Recorre los registros usando `for`.
# - [ ] Muestra un listado claro de la información.
# - [ ] Calcula al menos un resumen simple con contador o acumulador.
