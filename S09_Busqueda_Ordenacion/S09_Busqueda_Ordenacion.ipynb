# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/S09_Busqueda_Ordenacion.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 9: Búsqueda y ordenación de registros
#
# ## Objetivo
# Implementar búsqueda y ordenación sobre los registros almacenados en memoria para mejorar la consulta de información del proyecto.
#
# ## Producto de la sesión
# Construye un CRUD con búsqueda y ordenación de registros.
#
# ## Resultado esperado
# Busca registros por un campo clave y ordena la información almacenada para presentarla de forma útil.
#
# ## Alcance de la sesión
# - Búsqueda lineal.
# - Búsqueda binaria conceptual.
# - Ordenación básica por intercambio o selección.
# - Búsqueda por código, nombre u otro campo de la entidad.
# - Integración al menú del proyecto.

# %% [markdown]
# ## Base conceptual de la sesión
#
# **Búsqueda lineal** recorre los registros uno por uno hasta encontrar coincidencia.
#
# **Ordenación** reorganiza los registros según un criterio.
#
# **Cuidado con listas paralelas:** si se intercambia un nombre, también deben intercambiarse sus datos asociados.

# %% [markdown]
# ## Actividad práctica
#
# Agrega búsqueda y ordenación al proyecto.
#
# ### Opciones nuevas del menú
#
# 3. Buscar registro
# 4. Ordenar registros

# %%
nombres = ['Arroz', 'Azucar', 'Aceite']
precios = [4.5, 3.8, 9.9]
stocks = [20, 15, 8]

buscado = input('Nombre a buscar: ')
encontrado = False

for i in range(len(nombres)):
    if nombres[i].lower() == buscado.lower():
        print('Encontrado:', nombres[i], precios[i], stocks[i])
        encontrado = True

if not encontrado:
    print('No encontrado')

# %%
# Ordenación básica por nombre manteniendo listas paralelas
for i in range(len(nombres) - 1):
    for j in range(i + 1, len(nombres)):
        if nombres[i] > nombres[j]:
            nombres[i], nombres[j] = nombres[j], nombres[i]
            precios[i], precios[j] = precios[j], precios[i]
            stocks[i], stocks[j] = stocks[j], stocks[i]

for i in range(len(nombres)):
    print(nombres[i], precios[i], stocks[i])

# %% [markdown]
# ## Aprendizaje autónomo
#
# **1** Agrega búsqueda por otro campo de la entidad.
#
# **2** Agrega ordenación por un campo numérico.
#
# **3** Integra búsqueda y ordenación al menú del proyecto.
#
# **4** Prueba registros encontrados y no encontrados.

# %%
# Producto de sesión: CRUD con búsqueda y ordenación

# %% [markdown]
# ## Evaluación del producto de la sesión
#
# Lista de cotejo:
#
# - [ ] Implementa búsqueda lineal sobre registros en memoria.
# - [ ] Muestra un mensaje cuando el registro no existe.
# - [ ] Implementa ordenación por un criterio definido.
# - [ ] Mantiene la coherencia de los datos asociados al ordenar.
# - [ ] Integra búsqueda y ordenación al menú del proyecto.
