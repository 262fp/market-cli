# %% [markdown]
# # Sesión 16. Evaluación final y sustentaciones pendientes
#
# **Unidad:** Unidad III
# **Propósito:** Verificar individualmente las competencias del curso y completar las sustentaciones autorizadas.
# **Evidencia de la sesión:** Evidencia individual final y, cuando corresponda, sustentación pendiente.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Lectura y explicación de algoritmos.
# - Corrección o extensión breve de una solución.
# - Selección justificada de estructuras de datos.
# - Verificación de autoría y dominio individual.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
def buscar_por_codigo(productos, codigo):
    for producto in productos:
        if producto["codigo"] == codigo:
            return producto
    return None

datos = [{"codigo": "P01", "nombre": "Arroz"}]
assert buscar_por_codigo(datos, "P01")["nombre"] == "Arroz"
assert buscar_por_codigo(datos, "P99") is None

# %% [markdown]
# ## Reto de aplicación
#
# Resuelva y explique el caso individual asignado. Si corresponde, complete la demostración pendiente según las condiciones comunicadas por el docente.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] La solución es funcional y comprensible.
# - [ ] Justifica el algoritmo y la estructura utilizados.
# - [ ] Evidencia dominio individual del código.
