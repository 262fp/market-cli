# %% [markdown]
# <a href="https://colab.research.google.com/github/262fp/market-cli/blob/main/docs/S16_Evaluacion_Final.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 16: Evaluación final y sustentaciones pendientes
#
# ## Objetivo
# Evaluar de manera teórico-práctica los aprendizajes del curso y la comprensión técnica del producto desarrollado.
#
# ## Producto de la sesión
# Resuelve el examen final y sustenta aspectos técnicos de la aplicación de consola.
#
# ## Resultado esperado
# El estudiante demuestra dominio de pensamiento algorítmico, estructuras de control, estructuras de datos, funciones, archivos, estructuras de datos y explicación técnica del producto.
#
# ## Alcance de la sesión
# - Evaluación teórico-práctica.
# - Resolución de problemas integradores.
# - Revisión de conceptos clave.
# - Preguntas sobre el producto desarrollado.
# - Cierre académico del curso.

# %% [markdown]
# ## Temas de repaso
#
# - Entrada, proceso y salida.
# - Variables, operadores y conversiones.
# - Decisiones simples, compuestas y múltiples.
# - `for`, `while` y validación repetitiva.
# - Arreglos/listas.
# - Búsqueda y ordenación.
# - Funciones y recursividad.
# - Arreglos multidimensionales y paralelos.
# - Listas, pilas y colas.
# - Árboles y grafos a nivel introductorio.
# - Archivos e instantánea de datos.
# - Integración y sustentación técnica.

# %% [markdown]
# ## Indicaciones
#
# Lee cada problema completo antes de resolver. Identifica entradas, proceso, salida y casos de prueba. Cuando se solicite explicación, relaciona tu respuesta con el producto desarrollado durante el curso.

# %%
# Espacio para resolver ejercicios de evaluación final

# %% [markdown]
# ## Evaluación final
#
# Criterios generales:
#
# - [ ] Resuelve problemas aplicando la estructura adecuada.
# - [ ] Usa variables, decisiones, ciclos y estructuras de datos correctamente.
# - [ ] Modulariza soluciones cuando corresponde.
# - [ ] Lee o escribe archivos cuando el problema lo requiere.
# - [ ] Presenta resultados claros y verificables.
# - [ ] Explica técnicamente el funcionamiento de su producto.
