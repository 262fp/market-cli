# %% [markdown]
# # Sesión 01. Algoritmos, datos y modelo Entrada–Proceso–Salida
#
# **Unidad:** Unidad I
# **Propósito:** Representar una solución elemental antes de codificarla.
# **Evidencia de la sesión:** Algoritmo documentado y programa Python que transforma datos de entrada en una salida verificable.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Algoritmo, pseudocódigo y prueba de escritorio.
# - Modelo Entrada–Proceso–Salida (EPS).
# - Variables, constantes conceptuales y tipos básicos: int, float, str y bool.
# - Nombres significativos y trazabilidad entre el algoritmo y el código.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
producto = "Arroz"
precio = 4.80
cantidad = 3
subtotal = precio * cantidad

print(f"Producto: {producto}")
print(f"Subtotal: S/ {subtotal:.2f}")

# %% [markdown]
# ## Reto de aplicación
#
# Modele con EPS el cálculo del subtotal de un producto. Escriba el pseudocódigo, haga una prueba de escritorio y luego impleméntelo en Python.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] Identifica entradas, proceso y salida.`n- [ ] Usa tipos de datos pertinentes.`n- [ ] El resultado coincide con la prueba de escritorio.
