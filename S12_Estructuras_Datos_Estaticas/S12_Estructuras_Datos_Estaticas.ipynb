# %% [markdown]
# # Sesión 12. Estructuras de datos estáticas
#
# **Unidad:** Unidad III
# **Propósito:** Organizar datos tabulares y multidimensionales mediante estructuras de tamaño lógico definido.
# **Evidencia de la sesión:** Procesamiento de datos con arreglos bidimensionales, multidimensionales y paralelos.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Listas anidadas como matrices bidimensionales en Python.
# - Estructuras tridimensionales y multidimensionales.
# - Arreglos paralelos: correspondencia entre índices.
# - Registros, capacidad, recorrido y listado de datos.
# - Riesgos de desalineación en arreglos paralelos.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
# Filas: productos; columnas: ventas por día.
ventas = [
    [3, 2, 4],
    [1, 5, 2],
]
nombres = ["Arroz", "Leche"]

for i, fila in enumerate(ventas):
    print(nombres[i], "total:", sum(fila))

# Ejemplo 3D: local -> producto -> día
ventas_por_local = [ventas, [[2, 2, 1], [4, 1, 3]]]
print("Locales:", len(ventas_por_local))

# %% [markdown]
# ## Reto de aplicación
#
# Modele ventas por producto y período con una matriz; amplíela a dos locales y genere totales por fila. Compare esta opción con arreglos paralelos.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] Mantiene dimensiones e índices consistentes.
# - [ ] Recorre todos los niveles requeridos.
# - [ ] Explica cuándo evitaría arreglos paralelos.
