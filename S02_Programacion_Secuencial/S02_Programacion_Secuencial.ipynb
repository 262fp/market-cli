# %% [markdown]
# # Sesión 02. Programación secuencial
#
# **Unidad:** Unidad I
# **Propósito:** Construir algoritmos secuenciales con entrada, transformación y salida de datos.
# **Evidencia de la sesión:** Programa que calcula el importe de una línea de venta aplicando conversión de tipos.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Operadores aritméticos y de asignación.
# - Expresiones, precedencia y uso de paréntesis.
# - Conversión explícita con int, float y str.
# - Entrada con input y salida formateada con print.
# - Los operadores relacionales y lógicos se estudian en la sesión 3.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
nombre = input("Producto: ")
precio = float(input("Precio: "))
cantidad = int(input("Cantidad: "))
subtotal = precio * cantidad
igv = subtotal * 0.18
total = subtotal + igv

print(f"{nombre}: subtotal S/ {subtotal:.2f}, total S/ {total:.2f}")

# %% [markdown]
# ## Reto de aplicación
#
# Calcule subtotal, descuento e importe final de una operación usando únicamente una secuencia de instrucciones, sin condicionales ni ciclos.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] Convierte correctamente cada entrada.
# - [ ] Respeta la precedencia de las expresiones.
# - [ ] Presenta importes con formato legible.
