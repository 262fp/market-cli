# %% [markdown]
# # Sesión 11. Evaluación de la Unidad II
#
# **Unidad:** Unidad II
# **Propósito:** Integrar ciclos, listas, operaciones algorítmicas, recursividad, refactorización y persistencia básica.
# **Evidencia de la sesión:** Portafolio funcional y demostrable de la Unidad II.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Menú repetitivo y validaciones.
# - CRUD de datos en memoria.
# - Búsqueda, ordenamiento y acumulados.
# - Función recursiva con alcance pertinente.
# - Carga inicial y reemplazo de la instantánea de datos.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
def validar_portafolio(modulos):
    requeridos = {"menu", "crud", "algoritmos", "persistencia"}
    return requeridos.issubset(set(modulos))

assert validar_portafolio(["menu", "crud", "algoritmos", "persistencia"])
assert not validar_portafolio(["menu", "crud"])

# %% [markdown]
# ## Reto de aplicación
#
# Integre las evidencias de S6 a S10 en una aplicación CLI y demuestre el flujo completo con datos iniciales, operaciones en memoria y guardado final.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] El flujo se ejecuta sin intervención del docente en el código.
# - [ ] Los datos se conservan al reiniciar.
# - [ ] Sustenta el algoritmo y la estructura elegidos.
