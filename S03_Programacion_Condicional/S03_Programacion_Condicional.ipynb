# %% [markdown]
# # Sesión 03. Programación condicional
#
# **Unidad:** Unidad I
# **Propósito:** Tomar decisiones correctas a partir de reglas expresadas con condiciones booleanas.
# **Evidencia de la sesión:** Programa que aplica reglas de venta mediante condicionales simples, compuestas, múltiples y anidadas.
#
# > Implementación vigente: **Python 3**. La transición a Java 21 se realizará posteriormente.

# %% [markdown]
# ## Fundamentos
#
# - Operadores relacionales: ==, !=, <, <=, > y >=.
# - Operadores lógicos: and, or y not.
# - Expresiones booleanas y tablas de verdad aplicadas.
# - Condicionales simples, compuestas, múltiples con elif y anidadas.
# - Casos límite y selección de datos de prueba.

# %% [markdown]
# ## Práctica guiada en Python
#
# Ejecute, analice y modifique el siguiente ejemplo.

# %%
stock = 8
cantidad = 5
cliente_activo = True
total = 320.0

if not cliente_activo:
    mensaje = "Cliente inactivo"
elif cantidad <= 0:
    mensaje = "Cantidad inválida"
elif cantidad > stock:
    mensaje = "Stock insuficiente"
else:
    descuento = 0.10 if total >= 300 else 0.0
    mensaje = f"Venta válida. Descuento: {descuento:.0%}"

print(mensaje)

# %% [markdown]
# ## Reto de aplicación
#
# Implemente una regla que valide cliente, cantidad y stock, y que determine un descuento por rango. Pruebe casos válidos, inválidos y límites.

# %%
# Desarrolle aquí la solución del reto.

# %% [markdown]
# ## Criterios de cierre
#
# - [ ] Las condiciones son claras y no se contradicen.
# - [ ] Incluye los cuatro tipos de condicional solicitados.
# - [ ] Comprueba al menos cinco casos representativos.
